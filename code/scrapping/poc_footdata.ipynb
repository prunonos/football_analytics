# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.action_chains import ActionChains 
import pandas as pd
import soccerdata as sd
import importlib as il
# Out:
# C:\Users\GuillemUPV\soccerdata\config
# [06/29/24 16:07:09] INFO     No custom team name replacements found. You can configure these in       ]8;id=745406;file://c:\Users\GuillemUPV\Anaconda3\envs\tfg\lib\site-packages\soccerdata\_config.py\_config.py]8;;\:]8;id=206177;file://c:\Users\GuillemUPV\Anaconda3\envs\tfg\lib\site-packages\soccerdata\_config.py#85\85]8;;\
#                              C:\Users\GuillemUPV\soccerdata\config\teamname_replacements.json.
#                     INFO     Custom league dict loaded from                                          ]8;id=149738;file://c:\Users\GuillemUPV\Anaconda3\envs\tfg\lib\site-packages\soccerdata\_config.py\_config.py]8;;\:]8;id=444438;file://c:\Users\GuillemUPV\Anaconda3\envs\tfg\lib\site-packages\soccerdata\_config.py#161\161]8;;\
#                              C:\Users\GuillemUPV\soccerdata\config\league_dict.json.

# %%
from pathlib import Path

PATH_FOOTBALLDATA = 'F:\TFG\datasets\\football-data'
DATA_DIR = Path(PATH_FOOTBALLDATA + "/cache")

# %%
il.reload(sd)
LEAGUES = sd.MatchHistory.available_leagues()
LEAGUES
# Out:
# ['BEL-Jupiler League',
#  'ENG-Championship',
#  'ENG-Premier League',
#  'ESP-La Liga',
#  'FRA-Ligue 1',
#  'GER-Bundesliga',
#  'ITA-Serie A',
#  'NED-Eredivisie',
#  'POR',
#  'SP2',
#  'TUR-Ligi 1']

# %%
new_leagues = ['BEL-Jupiler League','ENG-Championship','NED-Eredivisie','POR','TUR-Ligi 1']

# %%
seasons = pd.read_csv('F:\TFG\datasets\\raw_datasets\\datalake.csv',sep=';',decimal=',')['season'].unique()
seasons = map(lambda t: t[1:],seasons)
seasons
# Out:
# <ipython-input-5-4163ac2c17e8>:1: DtypeWarning: Columns (14) have mixed types. Specify dtype option on import or set low_memory=False.
#   seasons = pd.read_csv('F:\TFG\datasets\\raw_datasets\\datalake.csv',sep=';',decimal=',')['season'].unique()

# %%
# mh = sd.MatchHistory(leagues=LEAGUES, seasons=[2122,2223,2324], data_dir=DATA_DIR)
# mh = sd.MatchHistory(leagues=new_leagues, seasons=seasons, data_dir=DATA_DIR)
mh = sd.MatchHistory(leagues='SP2', seasons=[2122,2223,2324], data_dir=DATA_DIR)
# Out:
# [06/29/24 16:08:04] INFO     Saving cached data to F:\TFG\datasets\football-data\cache                ]8;id=699362;file://c:\Users\GuillemUPV\Anaconda3\envs\tfg\lib\site-packages\soccerdata\_common.py\_common.py]8;;\:]8;id=55557;file://c:\Users\GuillemUPV\Anaconda3\envs\tfg\lib\site-packages\soccerdata\_common.py#89\89]8;;\

# %%
import numpy as np


np.array(mh.seasons)
# Out:
# array(['2122', '2223', '2324'], dtype='<U4')

# %%
np.array(mh.leagues)
# Out:
# array(['SP2'], dtype='<U3')

# %%
mh.read_games()
# Out:
#                                                                date  \

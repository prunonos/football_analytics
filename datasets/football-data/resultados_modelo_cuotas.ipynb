# %%
import pandas as pd

# %% [markdown]
# <h2>DATASET: Bet365 con resultado binario (yes/no)

# %%
ejemplo = pd.read_csv('C:\\Users\\GuillemUPV\\Documents\\Weka datasets\\dataset1.csv')
ejemplo
# Out:
#       CuotaLocal  CuotaVisitante Resultado
# 0       0.884956        0.047619       yes
# 1       0.523560        0.250000        no
# 2       0.578035        0.200000       yes
# 3       0.408163        0.333333        no
# 4       0.512821        0.238095        no
# ...          ...             ...       ...
# 3765    0.833333        0.090909       yes
# 3766    0.653595        0.142857        no
# 3767    0.465116        0.263158        no
# 3768    0.735294        0.117647       yes
# 3769    0.555556        0.210526       yes
#
# [3770 rows x 3 columns]

# %% [markdown]
# <h3>Como se distribuyen los datos?</h3>

# %% [markdown]
# <h3>Modelo predictivo</h3>
#
# Classify > FilteredClassifier
#
# Aplicamos un filtro de normalización o estandarización y seleccionamos un clasificador.

# %% [markdown]
# <b>OneR</b>
#
# ![image-3.png](attachment:image-3.png)
# ![image-4.png](attachment:image-4.png)
#
#
# <b>J48</b> con 66.2% y Cross-validation
# ![image-7.png](attachment:image-7.png)
# ![image-8.png](attachment:image-8.png)

# %% [markdown]
# Los resultados estandarizando los datos de entrada son ligeramente inferiores, pero no significativamente.

# %% [markdown]
# <h2>DATASET: Cuotas con resultado binario (yes/no)

# %% [markdown]
# <b>Distribución de los datos a partir de B365H (x) y B365A (y)</b>
#
# ![image.png](attachment:image.png)
#
# <b>yes</b>: azul | <b>no</b>: rojo

# %%
ejemplo = pd.read_csv('C:\\Users\\GuillemUPV\\Documents\\Weka datasets\\data_cuotas.csv')
ejemplo
# Out:
#          B365H     B365D     B365A       BWH       BWD       BWA       IWH  \
# 0     0.578035  0.266667  0.200000  0.561798  0.270270  0.217391  0.526316
# 1     0.833333  0.142857  0.076923  0.800000  0.166667  0.102564  0.819672
# 2     0.694444  0.238095  0.133333  0.666667  0.250000  0.153846  0.645161
# 3     0.476190  0.307692  0.266667  0.476190  0.312500  0.277778  0.476190
# 4     0.312500  0.303030  0.434783  0.322581  0.294118  0.434783  0.322581
# ...        ...       ...       ...       ...       ...       ...       ...
# 3765  0.476190  0.322581  0.266667  0.465116  0.307692  0.294118  0.476190
# 3766  0.602410  0.277778  0.173913  0.617284  0.270270  0.166667  0.588235
# 3767  0.523560  0.294118  0.250000  0.534759  0.285714  0.250000  0.526316
# 3768  0.476190  0.322581  0.250000  0.487805  0.307692  0.250000  0.500000
# 3769  0.454545  0.312500  0.277778  0.454545  0.312500  0.303030  0.454545
#
# ...

# %% [markdown]
# <b>Naive Bayes</b> con 64.2% de acierto y Train-Test 70-30%
# ![image.png](attachment:image.png)
#
# <b>Logistic</b> con 66.4% y Cross-validation-10
# ![image-2.png](attachment:image-2.png)
#
# <b>Logistic</b> con 65% y Train-Test 70-30%
# ![image-3.png](attachment:image-3.png)
#
# <b>J48</b> con 65.8% y Train-Test 70-30%
# ![image-4.png](attachment:image-4.png)
# ![image-5.png](attachment:image-5.png)

# %% [markdown]
# # FOOTBALL DATA

# %% [markdown]
# <h3>En esta página web hay una gran cantidad de ligas además de las principales.
# Los datos los actualizan 2 veces por semana.</h3>
#
# https://www.football-data.co.uk/data.php

# %%
import pandas as pd
import numpy as np
import os

# %%
os.getcwd()
# Out:
# 'F:\\2020-21\\Beca VRAIN\\datasets\\football-data'

# %% [markdown]
# He creado un diccionario donde van todas las ligas que he ojeado

# %%
# TODOS LOS DATAFRAMES
ligas = {}

# %% [markdown]
# Aquí guardamos en una lista con las temporadas de las cuales tenemos información en las diferentes ligas

# %%
lista_temporadas = []

for i in range(93,99):
    t = str(i)+''+str(i+1)
    lista_temporadas = [t] + lista_temporadas
    
t = '9900'
lista_temporadas = [t] + lista_temporadas
    
for i in range(0,21):
        j = str(i+1)
        i = str(i)
        x = (2) if len(i) == 1 else (1)
        i = i.zfill(x)
        x = (2) if len(j) == 1 else (1)
        j = j.zfill(x)
        t = i+''+j
        lista_temporadas = [t] + lista_temporadas

print(lista_temporadas)
# Out:
# ['2021', '1920', '1819', '1718', '1617', '1516', '1415', '1314', '1213', '1112', '1011', '0910', '0809', '0708', '0607', '0506', '0405', '0304', '0203', '0102', '0001', '9900', '9899', '9798', '9697', '9596', '9495', '9394']

# %% [markdown]
# <h4>Empezamos a leer las distintas ligas que tenemos</h4>
#
# He cambiado por codigo el nombre de los archivos para que indique liga y temporada a la que hace referencia (LIGA_temporada)

# %%
# PRIMERA DIVISIÓN - la he hecho un poco diferente al resto (es la primera que hice jeje)

ligas['LaLiga'] = {}

for i in range(10,21):
    f = str(i+1)
    season = str(i) + f
    t = pd.read_csv(os.getcwd()+'\\SP1_'+ season +'.csv')
    ligas['LaLiga'][season] = t
    
for i in range(0,9):
    f = str(i+1)
    season = '0' + str(i) + '0' + f
    if season == '0405': # error en esa temporada
        continue
    t = pd.read_csv(os.getcwd()+'\\SP1_'+ season +'.csv')
    ligas['LaLiga'][season] = t
        
for i in range(93,99):
    f = str(i+1)
    season = str(i) + f
    t = pd.read_csv(os.getcwd()+'\\SP1_'+ season +'.csv')
    ligas['LaLiga'][season] = t
    
    
# excepciones 0910 y 9900
ligas['LaLiga']['0910'] = pd.read_csv(os.getcwd()+'\\SP1_'+ '0910' +'.csv') 
ligas['LaLiga']['9900'] = pd.read_csv(os.getcwd()+'\\SP1_'+ '9900' +'.csv')

# %%
ligas['LaLiga'].keys()
# Out:
# dict_keys(['1011', '1112', '1213', '1314', '1415', '1516', '1617', '1718', '1819', '1920', '2021', '0001', '0102', '0203', '0304', '0506', '0607', '0708', '0809', '9394', '9495', '9596', '9697', '9798', '9899', '0910', '9900'])

# %% [markdown]
# <h3> QUE INFORMACIÓN NOS PROPORCIONA CADA DATAFRAME ? </h3>
#
# Vamos a ver por ejemplo con la temporada 2019-20 de LaLiga española.

# %%
ejemplo = ligas['LaLiga']['1920']
ejemplo
# Out:
#      Div        Date   Time    HomeTeam     AwayTeam  FTHG  FTAG FTR  HTHG  \
# 0    SP1  16/08/2019  20:00  Ath Bilbao    Barcelona     1     0   H     0
# 1    SP1  17/08/2019  16:00       Celta  Real Madrid     1     3   A     0
# 2    SP1  17/08/2019  18:00    Valencia     Sociedad     1     1   D     0
# 3    SP1  17/08/2019  19:00    Mallorca        Eibar     2     1   H     1
# 4    SP1  17/08/2019  20:00     Leganes      Osasuna     0     1   A     0
# ..   ...         ...    ...         ...          ...   ...   ...  ..   ...
# 375  SP1  19/07/2020  20:00     Granada   Ath Bilbao     4     0   H     1
# 376  SP1  19/07/2020  20:00     Leganes  Real Madrid     2     2   D     1
# 377  SP1  19/07/2020  20:00     Levante       Getafe     1     0   H     0
# 378  SP1  19/07/2020  20:00     Osasuna     Mallorca     2     2   D     1
# 379  SP1  19/07/2020  20:00     Sevilla     Valencia     1     0   H     0
#
#      HTAG  ... AvgC<2.5  AHCh  B365CAHH  B365CAHA  PCAHH  PCAHA  MaxCAHH  \
# 0       0  ...     1.97  0.75      1.93      2.00   1.91   2.01     2.02
# 1       1  ...     2.63  1.00      1.82      1.97   1.85   2.07     2.00
# 2       0  ...     1.82 -0.75      1.94      1.99   1.92   2.00     1.96
# 3       0  ...     1.66  0.00      2.11      1.82   2.09   1.83     2.12
# 4       0  ...     1.46 -0.50      1.89      2.04   1.90   2.01     1.95
# ..    ...  ...      ...   ...       ...       ...    ...    ...      ...
# 375     0  ...     1.78 -0.75      1.96      1.97   1.93   1.98     2.04
# 376     1  ...     2.06  0.25      2.03      1.90   2.05   1.87     2.06
# 377     0  ...     2.17  1.25      1.88      2.05   1.86   2.05     1.91
# 378     1  ...     2.30 -0.75      1.85      2.08   1.85   2.07     1.89
# 379     0  ...     2.35 -0.75      1.94      1.99   1.93   1.99     1.96
#
#      MaxCAHA  AvgCAHH  AvgCAHA
# 0       2.03     1.91     1.98
# 1       2.20     1.82     2.06
# 2       2.12     1.89     2.00
# 3       1.88     2.07     1.83
# 4       2.06     1.90     1.99
# ..       ...      ...      ...
# 375     1.99     1.93     1.94
# 376     1.93     2.00     1.88
# 377     2.08     1.86     2.01
# 378     2.11     1.84     2.04
# 379     2.00     1.92     1.95
#
# [380 rows x 105 columns]

# %%
ejemplo.shape # tenemos 105 columnas con características
# Out:
# (380, 105)

# %%
for c in ejemplo.columns:
    print(c)
# Out:
# Div
# Date
# Time
# HomeTeam
# AwayTeam
# FTHG
# FTAG
# FTR
# HTHG
# HTAG
# HTR
# HS
# AS
# HST
# AST
# HF
# AF
# HC
# AC
# HY
# AY
# HR
# AR
# B365H
# B365D
# B365A
# BWH
# BWD
# BWA
# IWH
# IWD
# IWA
# PSH
# PSD
# PSA
# WHH
# WHD
# WHA
# VCH
# VCD
# VCA
# MaxH
# MaxD
# MaxA
# AvgH
# AvgD
# AvgA
# B365>2.5
# B365<2.5
# P>2.5
# P<2.5
# Max>2.5
# Max<2.5
# Avg>2.5
# Avg<2.5
# AHh
# B365AHH
# B365AHA
# PAHH
# PAHA
# MaxAHH
# MaxAHA
# AvgAHH
# AvgAHA
# B365CH
# B365CD
# B365CA
# BWCH
# BWCD
# BWCA
# IWCH
# IWCD
# IWCA
# PSCH
# PSCD
# PSCA
# WHCH
# WHCD
# WHCA
# VCCH
# VCCD
# VCCA
# MaxCH
# MaxCD
# MaxCA
# AvgCH
# AvgCD
# AvgCA
# B365C>2.5
# B365C<2.5
# PC>2.5
# PC<2.5
# MaxC>2.5
# MaxC<2.5
# AvgC>2.5
# AvgC<2.5
# AHCh
# B365CAHH
# B365CAHA
# PCAHH
# PCAHA
# MaxCAHH
# MaxCAHA
# AvgCAHH
# AvgCAHA

# %% [markdown]
# Vamos a ver que significan algunas de estas características:

# %%
print(f'FTHG significa: {leyenda["FTHG"]}')
print(f'B365H significa: {leyenda["B365H"]}')
print(f'WHH significa: {leyenda["WHH"]}')
print(f'MaxAHA significa: {leyenda["MaxAHA"]}')
# Out:
# FTHG significa: Full Time Home Team Goals
# B365H significa: Bet365 home win odds
# WHH significa: William Hill home win odds
# MaxAHA significa: Market maximum Asian handicap away team odds

# %% [markdown]
# Por lo tanto en este dataset tenemos muchas caractéristicas basadas en las cuotas de las casas de apuestas

# %%
ejemplo[['HomeTeam','B365H','AwayTeam','B365A']]
# Out:
#        HomeTeam  B365H     AwayTeam  B365A
# 0    Ath Bilbao   5.25    Barcelona   1.65
# 1         Celta   4.75  Real Madrid   1.65
# 2      Valencia   1.66     Sociedad   5.50
# 3      Mallorca   2.80        Eibar   2.60
# 4       Leganes   2.00      Osasuna   4.20
# ..          ...    ...          ...    ...
# 375     Granada   2.00   Ath Bilbao   3.40
# 376     Leganes   2.62  Real Madrid   2.35
# 377     Levante   5.00       Getafe   1.66
# 378     Osasuna   1.75     Mallorca   4.20
# 379     Sevilla   1.90     Valencia   4.00
#
# [380 rows x 4 columns]

# %%
# SEGUNDA DIVISIÓN

for temp, num in zip(lista_temporadas,range(0,25)):
    for file in os.listdir(os.getcwd()):
        aux = '(' + str(num) + ')'
        if file.find('SP2 ' + aux) == False:
            os.rename('SP2 ' + aux + '.csv','SP2_' + temp + '.csv')

ligas['LaLiga2'] = {}

for temp in lista_temporadas:
    try:
        ligas['LaLiga2'][temp] = pd.read_csv(os.getcwd()+'\\SP2_'+ temp +'.csv')
    except Exception:
        print(temp + ' da error')
        continue
# Out:
# 0708 da error
# 0304 da error
# 0203 da error
# 0102 da error
# 9596 da error
# 9495 da error
# 9394 da error

# %% [markdown]
# <strong>ATENCION</strong><br>
# ¡¡¡ Hay algunas temporadas en algunas ligas que dan error al abrirse no sé porqué !!!

# %%
ligas['LaLiga2']['0405']
# Out:
#      Div        Date    HomeTeam    AwayTeam  FTHG  FTAG FTR  HTHG  HTAG HTR  \
# 0    SP2  28/08/2004       Eibar       Cadiz     2     1   H   2.0   0.0   H
# 1    SP2  28/08/2004      Lleida      Ferrol     1     2   A   0.0   1.0   A
# 2    SP2  28/08/2004  Pontevedra  Poli Ejido     0     1   A   0.0   0.0   D
# 3    SP2  28/08/2004    Tenerife       Elche     1     0   H   0.0   0.0   D
# 4    SP2  29/08/2004      Alaves  Valladolid     2     4   A   0.0   2.0   A
# ..   ...         ...         ...         ...   ...   ...  ..   ...   ...  ..
# 457  SP2  18/06/2005  Pontevedra   Salamanca     4     1   H   2.0   1.0   H
# 458  SP2  18/06/2005    Tenerife     Cordoba     0     2   A   0.0   1.0   A
# 459  SP2  18/06/2005    Terrassa    Malaga B     1     0   H   1.0   0.0   H
# 460  SP2  18/06/2005  Valladolid       Elche     1     2   A   1.0   1.0   D
# 461  SP2  18/06/2005       Xerez       Cadiz     0     2   A   0.0   1.0   A
#
#      ...  B365AHA  B365AH  Unnamed: 42  Unnamed: 43  Unnamed: 44  Unnamed: 45  \
# 0    ...      NaN     NaN          NaN          NaN          NaN          NaN
# 1    ...      NaN     NaN          NaN          NaN          NaN          NaN
# 2    ...      NaN     NaN          NaN          NaN          NaN          NaN
# 3    ...      NaN     NaN          NaN          NaN          NaN          NaN
# 4    ...      NaN     NaN          NaN          NaN          NaN          NaN
# ..   ...      ...     ...          ...          ...          ...          ...
# 457  ...     1.85    0.00          NaN          NaN          NaN          NaN
# 458  ...     2.00    0.25          NaN          NaN          NaN          NaN
# 459  ...     1.90   -0.25          NaN          NaN          NaN          NaN
# 460  ...     2.00   -0.50          NaN          NaN          NaN          NaN
# 461  ...     1.90    0.50          NaN          NaN          NaN          NaN
#
#      Unnamed: 46  Unnamed: 47  Unnamed: 48  Unnamed: 49
# 0            NaN          NaN          NaN          NaN
# 1            NaN          NaN          NaN          NaN
# 2            NaN          NaN          NaN          NaN
# 3            NaN          NaN          NaN          NaN
# 4            NaN          NaN          NaN          NaN
# ..           ...          ...          ...          ...
# 457          NaN          NaN          NaN          NaN
# 458          NaN          NaN          NaN          NaN
# 459          NaN          NaN          NaN          NaN
# 460          NaN          NaN          NaN          NaN
# 461          NaN          NaN          NaN          NaN
#
# [462 rows x 50 columns]

# %%
# PREMIER LEAGUE

for temp, num in zip(lista_temporadas,range(0,28)):
    for file in os.listdir(os.getcwd()):
        aux = '(' + str(num) + ')'
        if file.find('E0 ' + aux) == False:
            os.rename('E0 ' + aux + '.csv','E0_' + temp + '.csv')

ligas['PremierLeague'] = {}

for temp in lista_temporadas:
    try:
        ligas['PremierLeague'][temp] = pd.read_csv(os.getcwd()+'\\E0_'+ temp +'.csv')
    except Exception:
        continue

# %%
# SERIE A

for temp, num in zip(lista_temporadas,range(0,28)):
    for file in os.listdir(os.getcwd()):
        aux = '(' + str(num) + ')'
        if file.find('I1 ' + aux) == False:
            os.rename('I1 ' + aux + '.csv','I1_' + temp + '.csv')

ligas['SerieA'] = {}

for temp in lista_temporadas:
    try:
        ligas['SerieA'][temp] = pd.read_csv(os.getcwd()+'\\I1_'+ temp +'.csv')
    except Exception:
        continue

# %%
# BUNDESLIGA

for temp, num in zip(lista_temporadas,range(0,28)):
    for file in os.listdir(os.getcwd()):
        aux = '(' + str(num) + ')'
        if file.find('D1 ' + aux) == False:
            os.rename('D1 ' + aux + '.csv','D1_' + temp + '.csv')

ligas['Bundesliga'] = {}

for temp in lista_temporadas:
    try:
        ligas['Bundesliga'][temp] = pd.read_csv(os.getcwd()+'\\D1_'+ temp +'.csv')
    except Exception:
        continue

# %%
ligas['SerieA']['0102']
# Out:
#     Div      Date    HomeTeam    AwayTeam  FTHG  FTAG FTR  HTHG  HTAG HTR  \
# 0    I1  25/08/01     Bologna    Atalanta     1     0   H     1     0   H
# 1    I1  26/08/01     Brescia       Milan     2     2   D     2     0   H
# 2    I1  26/08/01  Fiorentina      Chievo     0     2   A     0     1   A
# 3    I1  26/08/01       Inter     Perugia     4     1   H     2     0   H
# 4    I1  26/08/01    Juventus     Venezia     4     0   H     3     0   H
# ..   ..       ...         ...         ...   ...   ...  ..   ...   ...  ..
# 301  I1  05/05/02       Parma     Venezia     2     1   H     1     1   D
# 302  I1  05/05/02     Perugia  Fiorentina     2     0   H     2     0   H
# 303  I1  05/05/02    Piacenza      Verona     3     0   H     1     0   H
# 304  I1  05/05/02      Torino        Roma     0     1   A     0     0   D
# 305  I1  05/05/02     Udinese    Juventus     0     2   A     0     2   A
#
#      ...  LBA   SBH    SBD    SBA   SYH   SYD    SYA    WHH   WHD    WHA
# 0    ...  NaN   NaN    NaN    NaN  1.91  3.00   3.75   1.90  3.00   3.75
# 1    ...  NaN   NaN    NaN    NaN  3.20  3.00   2.10   3.30  2.87   2.10
# 2    ...  NaN   NaN    NaN    NaN  1.40  3.75   7.00   1.44  3.75   6.00
# 3    ...  NaN   NaN    NaN    NaN  1.29  4.33   8.50   1.25  4.50  10.00
# 4    ...  NaN   NaN    NaN    NaN  1.20  5.00  11.00   1.20  5.00  11.00
# ..   ...  ...   ...    ...    ...   ...   ...    ...    ...   ...    ...
# 301  ...  NaN   NaN    NaN    NaN   NaN   NaN    NaN   1.33  4.00   8.00
# 302  ...  NaN   NaN    NaN    NaN   NaN   NaN    NaN   1.30  4.33   8.00
# 303  ...  NaN   2.0  2.375  4.500   NaN   NaN    NaN   2.00  2.37   5.00
# 304  ...  NaN   8.0  4.000  1.300   NaN   NaN    NaN  10.00  4.50   1.25
# 305  ...  NaN  10.0  4.500  1.182   NaN   NaN    NaN    NaN   NaN    NaN
#
# [306 rows x 28 columns]

# %% [markdown]
# Aquí he creado una leyenda a partir de un archivo .txt donde explica cada característica-

# %%
# CREAMOS UNA LEYENDA DE TODOS LOS ATRIBUTOS
# Las leyendas cambian de una liga a otra (por las casas de apuestas)

leyenda = {}

f = open(os.getcwd() + '\\notesSpanishLeague.txt') # cogiendo los atributos de la liga española
lineas = f.readlines()

for col in ligas['LaLiga']['2021'].columns:  # cogiendo los atributos de la liga española
    for linea in lineas:
        if linea.find(col) == False:
            lim = linea.find('= ')
            lim = lim+2
            res = linea[lim:-1]
            leyenda[col] = res
            lineas.remove(linea)

# %%
leyenda['FTR']
# Out:
# 'Full Time Result (H=Home Win, D=Draw, A=Away Win)'

# %%
leyenda.keys()
# Out:
# dict_keys(['Div', 'Date', 'Time', 'HomeTeam', 'AwayTeam', 'FTHG', 'FTAG', 'FTR', 'HTHG', 'HTAG', 'HTR', 'HS', 'AS', 'AST', 'HF', 'AF', 'HC', 'AC', 'HY', 'AY', 'HR', 'AR', 'B365H', 'B365D', 'B365A', 'BWH', 'BWD', 'BWA', 'IWH', 'IWD', 'IWA', 'PSH', 'PSD', 'PSA', 'WHH', 'WHD', 'WHA', 'VCH', 'VCD', 'VCA', 'MaxH', 'MaxD', 'MaxA', 'AvgH', 'AvgD', 'AvgA', 'B365>2.5', 'B365<2.5', 'P>2.5', 'P<2.5', 'Max>2.5', 'Max<2.5', 'Avg>2.5', 'Avg<2.5', 'AHh', 'B365AHA', 'PAHH', 'PAHA', 'MaxAHA', 'AvgAHA'])
